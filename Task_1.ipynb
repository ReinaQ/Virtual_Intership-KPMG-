# %%
import geocoder
import numpy as np
import pandas as pd
import datetime as dt

# %% [markdown]
# # Explore the Transactions

# %%
# Reading the file and skiping the first row which is just a note
transactions = pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx', sheet_name = 'Transactions', skiprows=1)
transactions.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# 0       71.49          53.62                  41245.0
# 1     2091.47         388.92                  41701.0
# 2     1793.43         248.82                  36361.0
# 3     1198.46         381.10                  36145.0
# 4     1765.30         709.48                  42226.0

# %%
# Check the info of the table
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(3), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# - Columns with missing values:online order, brand, product_line, product_class, product_size, standard_cost, product_first_sold_date columns
#
# - Wrong data type: product_first_sold_date columns is in float, but it should be datatime

# %%
# convert the datatype of the product_first_sold_date to datatime
# https://stackoverflow.com/questions/38454403/convert-excel-style-date-with-pandas
transactions['product_first_sold_date'] = pd.TimedeltaIndex(transactions['product_first_sold_date'], unit='d')+ dt.datetime(1900,1,1)
transactions['product_first_sold_date'].head()
# Out:
# 0   2012-12-04
# 1   2014-03-05
# 2   1999-07-22
# 3   1998-12-18
# 4   2015-08-12
# Name: product_first_sold_date, dtype: datetime64[ns]

# %%
transactions['product_first_sold_date'].tail()
# Out:
# 19995   2003-07-23
# 19996   1997-05-12
# 19997   2010-08-22
# 19998   2004-08-19
# 19999   1999-06-25
# Name: product_first_sold_date, dtype: datetime64[ns]

# %%
transactions['product_first_sold_date'].describe()
# Out:
# count                   19803
# unique                    100
# top       1992-10-04 00:00:00
# freq                      234
# first     1991-01-23 00:00:00
# last      2016-12-08 00:00:00
# Name: product_first_sold_date, dtype: object

# %%
# check the distribution of the transaction date and product_first_sold_date
# https://stackoverflow.com/questions/38792122/how-to-group-and-count-rows-by-month-and-year-using-pandas/38792452
transactions['transaction_date'].groupby([transactions['transaction_date'].dt.year]).agg('count')
# Out:
# transaction_date
# 2017    20000
# Name: transaction_date, dtype: int64

# %%
transactions['transaction_date'].groupby([transactions['transaction_date'].dt.month]).agg('count')
# Out:
# transaction_date
# 1     1682
# 2     1623
# 3     1656
# 4     1655
# 5     1685
# 6     1581
# 7     1717
# 8     1749
# 9     1572
# 10    1771
# 11    1665
# 12    1644
# Name: transaction_date, dtype: int64

# %%
transactions['product_first_sold_date'].groupby([transactions['product_first_sold_date'].dt.year]).agg('count')
# Out:
# product_first_sold_date
# 1991.0    1170
# 1992.0     445
# 1993.0    1360
# 1994.0     568
# 1995.0     415
# 1996.0     380
# 1997.0    1001
# 1998.0     403
# 1999.0     806
# 2000.0     370
# 2001.0     196
# 2002.0     568
# 2003.0    1545
# 2004.0    1224
# 2005.0     826
# 2006.0     770
# 2007.0     420
# 2008.0     213
# 2009.0     421
# 2010.0     816
# 2011.0    1342
# 2012.0    1044
# 2013.0     617
# 2014.0     547
# 2015.0    1146
# 2016.0    1190
# Name: product_first_sold_date, dtype: int64

# %%
transactions.describe()
# Out:
#        transaction_id   product_id   customer_id  online_order    list_price  \
# count    20000.000000  20000.00000  20000.000000  19640.000000  20000.000000
# mean     10000.500000     45.36465   1738.246050      0.500458   1107.829449
# std       5773.647028     30.75359   1011.951046      0.500013    582.825242
# min          1.000000      0.00000      1.000000      0.000000     12.010000
# 25%       5000.750000     18.00000    857.750000      0.000000    575.270000
# 50%      10000.500000     44.00000   1736.000000      1.000000   1163.890000
# 75%      15000.250000     72.00000   2613.000000      1.000000   1635.300000
# max      20000.000000    100.00000   5034.000000      1.000000   2091.470000
#
#        standard_cost
# count   19803.000000
# mean      556.046951
# std       405.955660
# min         7.210000
# 25%       215.140000
# 50%       507.580000
# 75%       795.100000
# max      1759.850000

# %%
# check missing values
transactions.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
# Find the unique values of online_order, which data type is float
transactions.online_order.unique()
# Out:
# array([ 0.,  1., nan])

# %%
transactions.order_status.unique()
# Out:
# array(['Approved', 'Cancelled'], dtype=object)

# %%
# check the unique values in each columns with missing values
transactions.brand.unique()
# Out:
# array(['Solex', 'Trek Bicycles', 'OHM Cycles', 'Norco Bicycles',
#        'Giant Bicycles', 'WeareA2B', nan], dtype=object)

# %%
transactions.product_line.unique()
# Out:
# array(['Standard', 'Road', 'Mountain', 'Touring', nan], dtype=object)

# %%
transactions.product_class.unique()
# Out:
# array(['medium', 'low', 'high', nan], dtype=object)

# %%
transactions.product_size.unique()
# Out:
# array(['medium', 'large', 'small', nan], dtype=object)

# %% [markdown]
# - Data types of brand, product_line, product_class, product_size are strings, we may drop those missing values if they are unnecessary for our analysis. However, the standard_cost and product_first_sold_date are precise number or time, the further processing of those missing values will depend on objective of the analysis;
# - All the values of columns mentioned above are accurate, consistent and valid

# %%
# Check the duplicates in the table
transactions[transactions.duplicated()].sum()
# Out:
# transaction_id             0.0
# product_id                 0.0
# customer_id                0.0
# transaction_date           0.0
# online_order               0.0
# order_status               0.0
# brand                      0.0
# product_line               0.0
# product_class              0.0
# product_size               0.0
# list_price                 0.0
# standard_cost              0.0
# product_first_sold_date    0.0
# dtype: float64

# %%
# save the dataframe as csv file without index
transactions.to_csv('transactions.csv', index=False)

# %% [markdown]
# # Explore the NewCustomerList

# %%
# import the NewCustomerList and skip the first row which is note
new_customer_list = pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx',sheet_name='NewCustomerList', skiprows=1)
new_customer_list.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  state    country  \
# 0      Mass Customer                  N      Yes  ...    QLD  Australia
# 1      Mass Customer                  N       No  ...    NSW  Australia
# 2  Affluent Customer                  N       No  ...    VIC  Australia
# 3  Affluent Customer                  N      Yes  ...    QLD  Australia
# 4  Affluent Customer                  N       No  ...    NSW  Australia
#
#    property_valuation Unnamed: 16 Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# 0                   6        0.56      0.7000       0.8750     0.743750
# 1                  11        0.75      0.7500       0.9375     0.796875
# 2                   5        0.65      0.6500       0.6500     0.650000
# 3                   1        0.83      1.0375       1.0375     1.037500
# 4                   9        0.96      0.9600       1.2000     1.200000
#
#    Unnamed: 20  Rank     Value
# 0            1     1  1.718750
# 1            1     1  1.718750
# 2            1     1  1.718750
# 3            4     4  1.703125
# 4            4     4  1.703125
#
# [5 rows x 23 columns]

# %%
# Drop Unnamed Columns which are not there in original table
cols = ['Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20']
new_customer_list = new_customer_list.drop(cols, axis=1)
new_customer_list.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes      14     45 Shopko Center
# 1      Mass Customer                  N       No      16    14 Mccormick Park
# 2  Affluent Customer                  N       No      10  5 Colorado Crossing
# 3  Affluent Customer                  N      Yes       5   207 Annamark Plaza
# 4  Affluent Customer                  N       No      19    115 Montana Place
#
#    postcode state    country  property_valuation  Rank     Value
# 0      4500   QLD  Australia                   6     1  1.718750
# 1      2113   NSW  Australia                  11     1  1.718750
# 2      3505   VIC  Australia                   5     1  1.718750
# 3      4814   QLD  Australia                   1     4  1.703125
# 4      2093   NSW  Australia                   9     4  1.703125

# %%
# Check the info of the table
new_customer_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    datetime64[ns]
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
#  11  address                              1000 non-null   object
#  12  postcode                             1000 non-null   int64
#  13  state                                1000 non-null   object
#  14  country                              1000 non-null   object
#  15  property_valuation                   1000 non-null   int64
#  16  Rank                                 1000 non-null   int64
#  17  Value                                1000 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(11)
# memory usage: 140.8+ KB

# %% [markdown]
# **For this stage:**
#
# - columns with missing values: last_name, DOB, job_title, job_industry_category;
# - Wrong data type: postcode should convert from int to string.

# %%
# convert the int into string in postcode
new_customer_list['postcode'] = new_customer_list['postcode'].astype(str)
print(new_customer_list['postcode'].dtypes)
# Out:
# object

# %%
# Check for null values
new_customer_list.isnull().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Rank                                     0
# Value                                    0
# dtype: int64

# %% [markdown]
# We will take the further step with the missing values based on the goal of final analysis.

# %%
# Check the duplicates in the table
new_customer_list[new_customer_list.duplicated()].sum()
# Out:
# first_name                             0.0
# last_name                              0.0
# gender                                 0.0
# past_3_years_bike_related_purchases    0.0
# DOB                                    0.0
# job_title                              0.0
# job_industry_category                  0.0
# wealth_segment                         0.0
# deceased_indicator                     0.0
# owns_car                               0.0
# tenure                                 0.0
# address                                0.0
# postcode                               0.0
# state                                  0.0
# country                                0.0
# property_valuation                     0.0
# Rank                                   0.0
# Value                                  0.0
# dtype: float64

# %% [markdown]
# There is no duplicates in the new_customer_list.

# %%
# check the descriptive statistics of new_customer_list
new_customer_list.describe()
# Out:
#        past_3_years_bike_related_purchases       tenure  property_valuation  \
# count                          1000.000000  1000.000000         1000.000000
# mean                             49.836000    11.388000            7.397000
# std                              27.796686     5.037145            2.758804
# min                               0.000000     0.000000            1.000000
# 25%                              26.750000     7.000000            6.000000
# 50%                              51.000000    11.000000            8.000000
# 75%                              72.000000    15.000000            9.000000
# max                              99.000000    22.000000           12.000000
#
#               Rank        Value
# count  1000.000000  1000.000000
# mean    498.819000     0.881714
# std     288.810997     0.293525
# min       1.000000     0.340000
# 25%     250.000000     0.649531
# 50%     500.000000     0.860000
# 75%     750.250000     1.075000
# max    1000.000000     1.718750

# %%
# check the validity and consistence of values in each columns
new_customer_list['DOB'].describe()
# Out:
# count                     983
# unique                    958
# top       1961-07-31 00:00:00
# freq                        2
# first     1938-06-08 00:00:00
# last      2002-02-27 00:00:00
# Name: DOB, dtype: object

# %%
# check the distribution of the DOB
new_customer_list['DOB'].groupby([new_customer_list['DOB'].dt.year]).agg('count')
# Out:
# DOB
# 1938.0    11
# 1939.0    13
# 1940.0    13
# 1941.0     9
# 1942.0     8
#           ..
# 1998.0    14
# 1999.0    19
# 2000.0    11
# 2001.0     9
# 2002.0     3
# Name: DOB, Length: 65, dtype: int64

# %%
new_customer_list['gender'].value_counts()
# Out:
# Female    513
# Male      470
# U          17
# Name: gender, dtype: int64

# %%
new_customer_list['job_title'].unique()
# Out:
# array(['General Manager', 'Structural Engineer', 'Senior Cost Accountant',
#        'Account Representative III', 'Financial Analyst',
#        'Assistant Media Planner', 'Compensation Analyst',
#        'Human Resources Assistant II', 'Speech Pathologist',
#        'Accounting Assistant IV', 'Programmer Analyst I',
#        'Environmental Specialist', 'Human Resources Manager',
#        'VP Marketing', 'Clinical Specialist', nan, 'Associate Professor',
#        'Actuary', 'Internal Auditor', 'Programmer I', 'Quality Engineer',
#        'Quality Control Specialist', 'Account Executive', 'Engineer II',
#        'Nurse', 'Librarian', 'Paralegal', 'Assistant Manager',
#        'Senior Quality Engineer', 'Recruiting Manager', 'Design Engineer',
#        'Business Systems Development Analyst', 'VP Quality Control',
#        'Cost Accountant', 'Product Engineer', 'Social Worker',
#        'Payment Adjustment Coordinator', 'Marketing Assistant',
#        'Recruiter', 'VP Product Management', 'Media Manager III',
#        'Developer I', 'Senior Financial Analyst', 'Electrical Engineer',
#        'Accountant IV', 'Executive Secretary', 'Account Representative I',
#        'Dental Hygienist', 'GIS Technical Architect',
#        'Assistant Professor', 'Mechanical Systems Engineer',
#        'Budget/Accounting Analyst IV', 'Research Nurse',
#        'Computer Systems Analyst IV', 'Analyst Programmer',
#        'Desktop Support Technician', 'Editor', 'Biostatistician IV',
#        'Database Administrator III', 'Engineer III',
#        'Physical Therapy Assistant', 'Director of Sales', 'Teacher',
#        'Human Resources Assistant IV', 'Nurse Practicioner',
#        'Structural Analysis Engineer', 'Marketing Manager',
#        'Staff Accountant IV', 'VP Sales', 'Accountant III',
#        'Sales Representative', 'Food Chemist', 'Staff Scientist',
#        'Geologist IV', 'Information Systems Manager', 'Junior Executive',
#        'Automation Specialist II', 'Software Consultant',
#        'Civil Engineer', 'Geological Engineer', 'Graphic Designer',
#        'Staff Accountant II', 'Community Outreach Specialist',
#        'Programmer Analyst II', 'Pharmacist', 'Senior Editor',
#        'Sales Associate', 'Developer II', 'Staff Accountant I',
#        'Environmental Tech', 'Account Coordinator', 'Health Coach II',
#        'Programmer Analyst III', 'Geologist III', 'Senior Developer',
#        'Account Representative II', 'Help Desk Technician',
#        'Research Assistant IV', 'Research Associate',
#        'Computer Systems Analyst I', 'Account Representative IV',
#        'Safety Technician I', 'Analog Circuit Design manager',
#        'Senior Sales Associate', 'Research Assistant II',
#        'Chief Design Engineer', 'Legal Assistant',
#        'Occupational Therapist', 'Statistician I', 'Technical Writer',
#        'Health Coach IV', 'Media Manager II', 'Professor',
#        'Safety Technician II', 'Software Test Engineer IV',
#        'Nuclear Power Engineer', 'Software Engineer II', 'Engineer IV',
#        'Database Administrator II', 'Chemical Engineer',
#        'Office Assistant II', 'Database Administrator I',
#        'Research Assistant I', 'Financial Advisor',
#        'Systems Administrator I', 'Systems Administrator IV', 'Operator',
#        'Office Assistant I', 'Software Engineer I', 'Programmer III',
#        'Media Manager I', 'Data Coordiator', 'Web Developer IV',
#        'Registered Nurse', 'Media Manager IV', 'Programmer II',
#        'Computer Systems Analyst II', 'Web Designer I',
#        'Human Resources Assistant I', 'Help Desk Operator',
#        'Systems Administrator III', 'Software Engineer III',
#        'Developer IV', 'Tax Accountant', 'Automation Specialist IV',
#        'VP Accounting', 'Accountant II', 'Administrative Assistant II',
#        'Programmer IV', 'Web Designer IV', 'Administrative Officer',
#        'Office Assistant IV', 'Accounting Assistant III',
#        'Accounting Assistant I', 'Research Assistant III',
#        'Web Developer II', 'Statistician III', 'Programmer Analyst IV',
#        'Accountant I', 'Project Manager', 'Budget/Accounting Analyst II',
#        'Automation Specialist III', 'Administrative Assistant I',
#        'Engineer I', 'Health Coach III', 'Statistician II',
#        'Developer III', 'Accounting Assistant II',
#        'Database Administrator IV', 'Budget/Accounting Analyst III',
#        'Software Test Engineer I', 'Health Coach I',
#        'Safety Technician IV', 'Computer Systems Analyst III',
#        'Budget/Accounting Analyst I', 'Staff Accountant III',
#        'Human Resources Assistant III', 'Statistician IV',
#        'Automation Specialist I', 'Systems Administrator II',
#        'Software Test Engineer II', 'Software Test Engineer III',
#        'Geologist I', 'Web Designer II', 'Web Developer I'], dtype=object)

# %%
new_customer_list['job_industry_category'].value_counts()
# Out:
# Financial Services    203
# Manufacturing         199
# Health                152
# Retail                 78
# Property               64
# IT                     51
# Entertainment          37
# Argiculture            26
# Telecommunications     25
# Name: job_industry_category, dtype: int64

# %%
new_customer_list['wealth_segment'].value_counts()
# Out:
# Mass Customer        508
# High Net Worth       251
# Affluent Customer    241
# Name: wealth_segment, dtype: int64

# %%
new_customer_list['deceased_indicator'].unique()
# Out:
# array(['N'], dtype=object)

# %%
new_customer_list['owns_car'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
new_customer_list['address'].unique()
# Out:
# array(['45 Shopko Center', '14 Mccormick Park', '5 Colorado Crossing',
#        '207 Annamark Plaza', '115 Montana Place', '89105 Pearson Terrace',
#        '7 Nevada Crossing', '85 Carioca Point', '717 West Drive',
#        '80 Scofield Junction', '3682 Crowley Point',
#        '3 Golden Leaf Point', '0484 North Avenue', '0591 Anzinger Circle',
#        '39 Kedzie Pass', '64 Granby Parkway', '610 Swallow Street',
#        '61 4th Street', '1550 Russell Way', '193 North Point',
#        '321 Raven Plaza', '656 Fuller Street', '1562 Merchant Street',
#        '663 8th Parkway', '67 Shelley Street', '75 Cordelia Trail',
#        '51 Hooker Court', '1859 Forest Circle', '44557 Rutledge Court',
#        '11184 East Drive', '555 Hermina Avenue', '8 Novick Trail',
#        '74 Welch Pass', '3 Pleasure Drive', '8 Dennis Point',
#        '41042 Lotheville Crossing', '2330 Butternut Trail',
#        '240 Acker Avenue', '04 Dexter Way', '011 Northland Trail',
#        '8 Grayhawk Circle', '44 Darwin Lane', '2548 Arrowood Pass',
#        '938 Ilene Road', '6 Melby Center', '08708 Moulton Park',
#        '306 Clemons Junction', '18 Grim Road', '169 Bashford Drive',
#        '3 Vermont Lane', '998 Gale Park', '64 Mcguire Trail',
#        '74127 Blaine Point', '31756 Meadow Valley Lane',
#        '293 Mayfield Street', '261 Grayhawk Way', '2 Schlimgen Terrace',
#        '76733 Sunbrook Terrace', '683 Florence Way',
#        '7232 Fulton Parkway', '06936 Bobwhite Circle', '283 Acker Drive',
#        '9 Mosinee Parkway', '45 Becker Place', '27 Karstens Crossing',
#        '9630 Cottonwood Avenue', '989 Graedel Terrace',
#        '76 Bartelt Center', '29778 Mendota Drive', '69 Algoma Center',
#        '8288 Lyons Way', '4185 Florence Trail', '9608 Heffernan Drive',
#        '9 Union Center', '800 Emmet Park', '12351 Spenser Pass',
#        '4 Valley Edge Plaza', '1601 Rutledge Lane', '0 Mockingbird Plaza',
#        '1665 Kenwood Center', '5 4th Center', '92214 Spenser Road',
#        '5186 Main Trail', '564 Forest Dale Avenue', '83 Old Gate Point',
#        '387 Dixon Alley', '411 Twin Pines Way', '12 Arapahoe Park',
#        '4915 Debra Center', '76 Sunnyside Avenue', '1 Talisman Avenue',
#        '91164 Washington Terrace', '74 Carpenter Street',
#        '6776 Anderson Center', '1 Orin Hill', '88 Annamark Avenue',
#        '37439 High Crossing Circle', '5 Nevada Point',
#        '67 Grayhawk Circle', '0 Meadow Ridge Street', '5 Quincy Street',
#        '13025 Johnson Plaza', '966 Sunnyside Center', '802 Mallory Park',
#        '93 Judy Drive', '94 Manitowish Court', '5013 Erie Crossing',
#        '540 Sachs Road', '422 Forster Circle', '4275 Bluestem Pass',
#        '6 Anderson Junction', '276 Westend Road', '69 Garrison Point',
#        '65 Milwaukee Hill', '4252 Dovetail Pass', '56 Riverside Street',
#        '7 Cascade Park', '29307 Russell Avenue', '3 Mcguire Crossing',
#        '6 Golf View Alley', '83716 Russell Lane', '265 Stephen Trail',
#        '2 Charing Cross Trail', '8350 Moulton Terrace',
#        '578 Waywood Circle', '9722 Northport Way', '7026 Katie Lane',
#        '8 Eggendart Pass', '1 Bluejay Place', '28970 Monument Lane',
#        '235 Mendota Court', '49309 Redwing Lane', '367 Bay Point',
#        '932 Glendale Avenue', '492 Waywood Lane', '12683 Mifflin Point',
#        '6160 Weeping Birch Hill', '7 Oakridge Lane', '0 Dexter Parkway',
#        '75813 Lawn Lane', '74613 Northport Park', '68 Karstens Pass',
#        '87254 Hermina Pass', '801 Atwood Alley', '2 Morrow Alley',
#        '92934 Mallory Trail', '90820 Thackeray Street',
#        '48 Ludington Plaza', '49185 Derek Circle',
#        '0721 Meadow Ridge Pass', '115 Westridge Road', '7 Myrtle Lane',
#        '7795 Memorial Drive', '24695 Boyd Road', '95306 John Wall Avenue',
#        '6704 Pine View Lane', '98158 Alpine Point', '33652 Lyons Alley',
#        '8 Debs Road', '101 Starling Pass', '35151 Bunker Hill Crossing',
#        '2093 Amoth Pass', '57343 Eagan Avenue', '83 Armistice Terrace',
#        '5388 Burrows Alley', '5612 Toban Point', '65 Ridge Oak Court',
#        '74 Russell Terrace', '255 Loeprich Lane', '67 Northport Avenue',
#        '823 Wayridge Trail', '5 Golf Terrace', '40809 Truax Way',
#        '1398 Burning Wood Way', '3920 Swallow Junction', '4 Warner Park',
#        '534 Lien Lane', '48 Shoshone Park', '170 Briar Crest Place',
#        '0193 Northland Street', '5219 Pearson Drive',
#        '6156 Summit Center', '803 Badeau Point', '735 Westridge Road',
#        '1190 Hanson Street', '370 Division Junction', '90 Northport Hill',
#        '77785 Veith Lane', '232 Knutson Park', '25805 Eagan Place',
#        '743 Debra Court', '6966 Delladonna Street',
#        '98221 Pennsylvania Place', '307 Knutson Center',
#        '593 Alpine Drive', '45788 Stang Plaza', '96515 Di Loreto Pass',
#        '8625 Dakota Plaza', '02 Hoffman Road', '496 Logan Center',
#        '6065 Talisman Crossing', '72 Eliot Place', '67 Bluejay Plaza',
#        '518 Paget Hill', '87107 Shelley Crossing', '3 Mallory Circle',
#        '1582 Bashford Drive', '3 Homewood Park', '06 Old Gate Park',
#        '49 Surrey Point', '59254 Northland Alley', '4 North Drive',
#        '89 Parkside Street', '7 Hazelcrest Place', '013 David Junction',
#        '840 Graceland Street', '6 Lotheville Trail', '890 Truax Lane',
#        '72922 Cambridge Terrace', '60461 Esch Avenue', '6 Novick Alley',
#        '76 Donald Trail', '1607 Westridge Drive', '3630 Dawn Crossing',
#        '29007 Dapin Street', '68 Fairfield Street', '6 Iowa Center',
#        '5 Briar Crest Road', '945 Bobwhite Court', '2 Glendale Center',
#        '21824 Northridge Alley', '68 Anthes Park', '3 Anthes Court',
#        '036 Redwing Street', '92 Petterle Place', '72008 7th Avenue',
#        '87 Sheridan Junction', '811 Melrose Park', '2 Logan Avenue',
#        '538 Gina Way', '52761 Portage Crossing', '8 Fieldstone Street',
#        '8957 Anhalt Alley', '5 High Crossing Junction',
#        '75760 Toban Junction', '178 Waxwing Trail', '8648 Green Alley',
#        '08912 Carberry Place', '720 Menomonie Crossing',
#        '0686 Hallows Trail', '6668 Blue Bill Park Plaza',
#        '06 Dwight Park', '5202 Crowley Place', '14709 Portage Avenue',
#        '895 Glendale Park', '0474 Bowman Hill', '652 Fuller Terrace',
#        '5356 Sugar Plaza', '7 Schiller Point', '9193 Prairieview Drive',
#        '13272 Basil Avenue', '29 Aberg Crossing', '4 Monterey Road',
#        '416 Lighthouse Bay Lane', '05475 Elgar Place',
#        '343 Lakewood Center', '47 Kim Terrace', '590 Hagan Parkway',
#        '94694 Eagle Crest Terrace', '261 Orin Center',
#        '667 Waxwing Plaza', '83509 Delaware Street', '88 Mifflin Pass',
#        '10 Dexter Park', '3 Sundown Hill', '655 Glendale Trail',
#        '39192 Glendale Alley', '7307 Lake View Crossing',
#        '1199 Express Plaza', '1 Namekagon Point', '602 Meadow Vale Lane',
#        '6784 Spohn Alley', '67 Shelley Crossing', '07 Dayton Court',
#        '351 Sunfield Lane', '8427 Moulton Place', '984 Del Sol Junction',
#        '3 Pepper Wood Hill', '8737 Scoville Center', '385 Montana Place',
#        '3 Surrey Court', '2 Magdeline Street', '93235 Hoard Trail',
#        '356 Carberry Avenue', '71 Ludington Center',
#        '2116 Continental Terrace', '2 7th Way', '7 Elgar Road',
#        '00003 Hoffman Pass', '71 Stone Corner Avenue', '0 Esker Avenue',
#        '61825 Debs Terrace', '11 Oak Terrace', '7 Michigan Hill',
#        '8 Randy Park', '0 Mayfield Parkway', '57903 Hanson Parkway',
#        '763 Ridgeway Place', '99 Westend Court', '5 Caliangt Center',
#        '4472 Washington Junction', '31675 Corry Way',
#        '4882 Dakota Center', '4 Warner Circle',
#        '4 Manufacturers Crossing', '016 Westport Park', '19 Debs Parkway',
#        '665 Sachs Way', '4110 Mifflin Center', '62 Spaight Center',
#        '3 Express Lane', '7353 Mallard Junction', '066 Warner Trail',
#        '52752 Barby Hill', '57025 New Castle Street', '0 Stoughton Park',
#        '49 Jana Point', '7 Fordem Point', '797 Westend Street',
#        '5316 Farwell Hill', '770 Crest Line Parkway',
#        '50 American Street', '4793 Mcbride Pass', '01124 Dottie Lane',
#        '42681 Carey Alley', '2941 Talisman Alley', '990 Hoffman Avenue',
#        '5 Summer Ridge Court', '102 Charing Cross Terrace',
#        '5 Trailsway Avenue', '23694 Leroy Place', '53 Memorial Street',
#        '691 Valley Edge Alley', '60073 Pankratz Pass',
#        '8 Schlimgen Drive', '0237 Mallard Place',
#        '69710 Northfield Center', '1 Kinsman Crossing',
#        '40553 Rigney Avenue', '48578 Farmco Park',
#        '91634 Badeau Crossing', '391 Old Shore Lane',
#        '28 Golf View Terrace', '0197 Sachs Avenue', '48297 Stuart Circle',
#        '67 Heath Circle', '3 Sheridan Lane', '04 Oakridge Plaza',
#        '78 Clarendon Drive', '335 Cambridge Hill',
#        '5675 Burning Wood Trail', '4597 Marcy Point', '9 Walton Way',
#        '27429 Dottie Plaza', '42 Donald Hill', '3 Hoepker Parkway',
#        '19561 Express Street', '41 Kropf Road', '0516 Fremont Point',
#        '7872 South Junction', '81 Donald Parkway', '105 Carpenter Court',
#        '58231 Tomscot Plaza', '3 Loeprich Point', '5773 Acker Way',
#        '540 Katie Street', '9495 Jenna Way', '66 Ruskin Parkway',
#        '9736 Mitchell Pass', '9 Springview Terrace',
#        '1914 Oakridge Place', '179 Anzinger Center', '62 Melrose Court',
#        '84650 Novick Point', '5 Hoard Parkway', '376 Talmadge Street',
#        '5979 Green Ridge Way', '2972 Holy Cross Crossing',
#        '89 Riverside Court', '540 Forest Run Plaza',
#        '817 Bunker Hill Place', '4669 Troy Place', '02 Roth Drive',
#        '7 Northridge Court', '5735 Starling Plaza', '97 Transport Plaza',
#        '67183 Anniversary Parkway', '2 Emmet Parkway',
#        '61926 Tomscot Hill', '07 Susan Lane', '43094 Kedzie Pass',
#        '678 Lyons Trail', '1832 Burning Wood Place', '5642 Debs Terrace',
#        '73 Riverside Trail', '05 Everett Trail', '082 Welch Lane',
#        '72 Mccormick Circle', '15669 Arizona Trail',
#        '79 Armistice Parkway', '330 Melby Terrace', '2637 Monument Trail',
#        '37919 Old Gate Park', '00 Judy Terrace', '79 Armistice Junction',
#        '7 Clemons Circle', '6455 Mayfield Street',
#        '7873 Meadow Vale Plaza', '45 Banding Hill', '53 Moulton Avenue',
#        '7 Sauthoff Park', '9082 Waywood Avenue', '30049 Brown Road',
#        '7 Huxley Trail', '3 Service Center', '0627 Golf Center',
#        '24960 Shopko Crossing', '43 Stoughton Drive',
#        '247 Blue Bill Park Parkway', '2 David Pass', '3867 Barby Hill',
#        '52 Bobwhite Court', '32249 Sycamore Way', '3 Roth Junction',
#        '72423 Surrey Street', '76 Green Ridge Drive',
#        '9 Glacier Hill Circle', '91281 Transport Center', '11 Paget Road',
#        '3686 Waubesa Way', '6 Killdeer Way', '737 Service Lane',
#        '253 Katie Junction', '481 Moulton Place', '3864 Sheridan Alley',
#        '61416 Karstens Place', '0 Union Parkway', '4 Lukken Lane',
#        '1507 Schlimgen Trail', '4 Meadow Ridge Place', '31 Melody Circle',
#        '96 Rutledge Drive', '2905 Towne Place', '638 Caliangt Avenue',
#        '9645 Moose Terrace', '7 Messerschmidt Crossing',
#        '005 Loeprich Way', '3653 Steensland Road', '56 Comanche Terrace',
#        '66 Merry Court', '92 Ludington Street', '37 Rigney Park',
#        '0796 Barnett Plaza', '415 Rockefeller Trail',
#        '846 Loftsgordon Crossing', '9 Ridgeview Avenue',
#        '6218 Delladonna Parkway', '095 Glacier Hill Circle',
#        '057 Victoria Crossing', '0 Memorial Road', '409 Starling Lane',
#        '36963 Pierstorff Terrace', '8069 Sunbrook Way', '9 Hovde Way',
#        '94 Barby Lane', '0492 Kings Street', '1 Fair Oaks Alley',
#        '780 Norway Maple Hill', '625 Mandrake Junction', '1037 Roth Park',
#        '315 Center Park', '1 Graceland Plaza', '98555 Victoria Hill',
#        '31121 Pierstorff Center', '59 Garrison Terrace',
#        '2763 Buhler Circle', '309 Maple Wood Pass', '777 Fairfield Court',
#        '99 Quincy Parkway', '902 Westend Lane', '9 Rieder Junction',
#        '734 Veith Way', '0800 Dahle Alley', '5 Macpherson Drive',
#        '07 Boyd Drive', '427 Oak Avenue', '390 Express Plaza',
#        '703 Ludington Plaza', '7 Dayton Circle', '79 Manufacturers Plaza',
#        '600 Artisan Drive', '0 Veith Way', '2336 Continental Point',
#        '535 Corben Point', '1690 Forster Place', '54 6th Trail',
#        '16 Pepper Wood Junction', '4 Arapahoe Terrace',
#        '540 Farragut Avenue', '938 Bartillon Hill', '612 Annamark Center',
#        '18 Sage Plaza', '4 Randy Street', '05 Corry Center',
#        '1 South Street', '4810 Kim Park', '80388 Ryan Place',
#        '1092 Kinsman Parkway', '1 Bluejay Court', '7 Maple Wood Plaza',
#        '12 Eastlawn Terrace', '24929 Spaight Junction',
#        '846 Daystar Lane', '36 Golf Course Circle', '0 Nelson Crossing',
#        '93264 Almo Plaza', '2109 Shoshone Court', '355 Roxbury Lane',
#        '2 Warrior Crossing', '08470 Kingsford Lane', '16898 Donald Plaza',
#        '3128 Mallory Pass', '799 Luster Road', '53 Dryden Trail',
#        '5512 Ronald Regan Hill', '72 Melrose Street', '3460 Dapin Street',
#        '5 Hovde Lane', '4 Gale Center', '5263 Stone Corner Crossing',
#        '0439 Mandrake Park', '069 Hoard Pass', '89 Green Ridge Point',
#        '8 Cardinal Junction', '240 Main Hill', '67081 Burrows Center',
#        '0 Kipling Way', '1 Raven Way', '261 Holy Cross Park',
#        '891 Ohio Terrace', '1408 Hovde Circle', '50897 Northfield Road',
#        '596 Boyd Park', '8 Fordem Place', '656 Kennedy Crossing',
#        '2 Jackson Place', '39408 Manufacturers Road',
#        '168 Schlimgen Center', '8 Kim Avenue', '920 Cambridge Way',
#        '4 Schlimgen Trail', '31 Mccormick Court', '65 Milwaukee Lane',
#        '76 Mendota Park', '26667 Rigney Place', '898 Muir Court',
#        '88093 Pierstorff Plaza', '3319 Anthes Crossing',
#        '16 Mosinee Place', '197 Northport Plaza', '10236 Mifflin Avenue',
#        '5287 Clarendon Plaza', '38407 Sutteridge Circle',
#        '423 Holy Cross Lane', '0307 Namekagon Crossing',
#        '743 Stuart Terrace', '1478 Oak Valley Park',
#        '8970 Anhalt Junction', '563 Waywood Park', '9313 Mayer Street',
#        '2978 Mccormick Center', '527 Jay Trail', '6 Loftsgordon Pass',
#        '9940 Manley Drive', '0736 West Crossing', '95796 Mcbride Drive',
#        '20187 Loomis Court', '17393 Colorado Hill', '65 Rutledge Parkway',
#        '02023 Loeprich Drive', '9107 Pine View Plaza',
#        '822 Di Loreto Junction', '2712 Namekagon Crossing',
#        '32 Hazelcrest Court', '9 Forster Circle', '07226 Anzinger Avenue',
#        '936 Porter Lane', '6 Havey Pass', '882 Toban Lane',
#        '844 Forster Place', '42590 Bellgrove Court',
#        '6060 Veith Crossing', '25 Lakeland Point', '21667 Randy Crossing',
#        '608 Dapin Court', '8738 Lukken Terrace', '8634 Wayridge Pass',
#        '5 Homewood Road', '7 Dunning Avenue', '67 Beilfuss Plaza',
#        '976 Roxbury Alley', '2 Main Lane', '6115 Forest Crossing',
#        '432 Ronald Regan Court', '8600 Forster Lane',
#        '6692 Independence Way', '770 Farmco Point', '602 Toban Center',
#        '74 Shopko Pass', '804 Washington Point', '97 Merrick Center',
#        '29 Tennyson Alley', '8194 Lien Street', '9503 New Castle Street',
#        '0 Emmet Trail', '7 Spaight Drive', '45000 Randy Court',
#        '65 David Pass', '7 Golden Leaf Avenue', '43 Dayton Drive',
#        '5 Dryden Road', '14183 Iowa Center', '95 Del Mar Court',
#        '98 Shoshone Road', '7199 Springview Parkway',
#        '045 Magdeline Court', '5 Hoard Trail', '93 Scofield Pass',
#        '2 Ridgeway Avenue', '29 Maple Trail', '7 Brentwood Circle',
#        '28 Hazelcrest Drive', '01 Reindahl Circle', '5880 Hauk Street',
#        '0 Larry Park', '69 Sunfield Terrace', '7513 Swallow Drive',
#        '058 Morningstar Center', '0689 Melby Park', '3 Spohn Circle',
#        '91 Calypso Trail', '43863 Victoria Lane',
#        '54782 Lake View Parkway', '48971 Marquette Point',
#        '99 Sherman Parkway', '381 Emmet Terrace', '7 Beilfuss Road',
#        '37068 Montana Street', '7 Elgar Hill', '36506 Bartillon Point',
#        '8 Scott Drive', '653 2nd Park', '22 Shelley Plaza',
#        '504 Stuart Pass', '5 Red Cloud Place', '264 Valley Edge Pass',
#        '5 Southridge Hill', '539 Graceland Pass', '22435 Barnett Court',
#        '46057 Harbort Hill', '2 Shasta Place', '77608 Donald Center',
#        '0433 La Follette Road', '8593 Prairie Rose Way',
#        '179 Carey Terrace', '3 Ruskin Hill', '87 Crescent Oaks Alley',
#        '08822 Duke Road', '5 Schurz Street', '344 Darwin Junction',
#        '320 Acker Drive', '2874 Bay Hill', '3 Sunbrook Alley',
#        '34 Jay Hill', '78 Bluestem Road', '0 Express Lane',
#        '077 Hansons Point', '23737 Bartillon Street',
#        '2 Anniversary Trail', '05 Ronald Regan Alley',
#        '738 Spaight Drive', '8 Bunker Hill Court', '59846 2nd Pass',
#        '3745 Thierer Trail', '11121 Jackson Crossing', '1 Elgar Alley',
#        '32834 Caliangt Way', '27185 Fisk Drive', '2 Harper Junction',
#        '7 Caliangt Street', '5331 Ilene Parkway', '1009 Roxbury Point',
#        '660 Carey Avenue', '25 Oneill Alley', '2 Golden Leaf Parkway',
#        '18 Dottie Park', '85 Badeau Pass', '784 Lotheville Court',
#        '57568 Northview Junction', '283 Golf View Lane', '7 Johnson Hill',
#        '22580 Doe Crossing Drive', '96081 Lakewood Hill',
#        '6634 Old Gate Parkway', '72 Lukken Crossing',
#        '6 Meadow Ridge Pass', '290 Menomonie Circle',
#        '6 Sutherland Parkway', '1 Oriole Crossing', '51837 Canary Center',
#        '43030 Carberry Way', '0 Bay Drive', '6 Anzinger Pass',
#        '19453 Ramsey Point', '1861 Chive Court', '9 Westerfield Point',
#        '3 Redwing Center', '189 Bayside Court', '174 Farwell Point',
#        '356 Pennsylvania Point', '62 Dryden Junction',
#        '25 Westerfield Road', '64 Armistice Point', '74 Everett Court',
#        '38 Nobel Lane', '6936 Homewood Avenue', '8 Crowley Center',
#        '44 Ronald Regan Parkway', '174 Lotheville Crossing',
#        '8 Bluejay Road', '4286 Rowland Circle', '44 Thompson Center',
#        '70360 Onsgard Plaza', '53870 Jay Pass', '417 Killdeer Alley',
#        '28 Prentice Trail', '216 Bultman Park', '435 Mitchell Street',
#        '15621 Twin Pines Crossing', '03 Bellgrove Avenue',
#        '89100 Rusk Crossing', '82 Gina Junction', '077 Dennis Lane',
#        '42280 Namekagon Crossing', '1 Fordem Way', '780 Bonner Pass',
#        '77916 Moland Park', '00 Southridge Avenue',
#        '7870 Stuart Crossing', '4 Vera Pass', '7234 Sycamore Pass',
#        '98454 Dapin Park', '4 Talmadge Road', '47 Susan Park',
#        '7 Ramsey Trail', '6026 Mallory Drive', '1 Eliot Plaza',
#        '66 Hoffman Court', '7 Sycamore Terrace',
#        '31281 Meadow Valley Way', '28 Parkside Park',
#        '2782 Northridge Street', '3662 Beilfuss Lane',
#        '56334 Vera Crossing', '79 Sheridan Point', '95960 Warner Parkway',
#        '04769 Dahle Plaza', '5731 Bunker Hill Lane',
#        '89244 Macpherson Trail', '922 Utah Avenue', '25044 Bay Avenue',
#        '315 Hudson Road', '6112 Mariners Cove Park', '176 Fallview Plaza',
#        '544 Pawling Road', '11 Brickson Park Alley', '77 Paget Park',
#        '598 Memorial Place', '6227 Quincy Terrace',
#        '31351 Sunbrook Place', '80 Schiller Center', '1217 Melody Alley',
#        '46 Westerfield Place', '75024 Ronald Regan Hill', '15 Fisk Road',
#        '96 Hermina Place', '99376 Namekagon Street', '276 Derek Circle',
#        '56766 Mariners Cove Place', '13 Montana Place',
#        '1969 Melody Lane', '02463 Portage Center', '383 Graceland Avenue',
#        '005 Kensington Street', '1 Alpine Crossing', '2 Namekagon Trail',
#        '6771 Pleasure Terrace', '2632 Del Mar Point', '7021 5th Alley',
#        '602 Clove Center', '04153 Johnson Point', '9 Spohn Way',
#        '6030 Becker Plaza', '4 Mallory Pass', '64037 Swallow Crossing',
#        '4594 Jackson Hill', '4 Anzinger Street', '33 Pond Point',
#        '1 Roth Plaza', '0593 Stoughton Center', '8042 Cherokee Court',
#        '5864 Mcbride Trail', '180 Lakewood Park', '6 Union Center',
#        '41153 Pond Park', '6233 Fulton Point', '05123 Bobwhite Plaza',
#        '3413 Schmedeman Court', '4189 Laurel Center', '76 Melody Avenue',
#        '1 Mcguire Lane', '8734 Fulton Hill', '660 Hallows Place',
#        '43 Pond Junction', '6195 Bellgrove Lane', '768 Southridge Drive',
#        '63386 Talisman Hill', '30738 Muir Avenue', '3259 Eagan Parkway',
#        '160 Fremont Point', '266 Lakewood Terrace', '5280 Waxwing Point',
#        '192 South Junction', '900 Victoria Way', '06 Main Alley',
#        '22 Muir Avenue', '4871 Caliangt Hill', '47776 Packers Street',
#        '535 Graedel Circle', '9 Stephen Center', '074 Badeau Crossing',
#        '4897 Melody Road', '096 Gateway Road', '68 Bluestem Center',
#        '6 Maple Plaza', '6812 Gina Point', '1 Becker Parkway',
#        '52201 Tony Avenue', '2382 Anthes Crossing', '44350 Buell Alley',
#        '23 Del Sol Alley', '79 Mockingbird Plaza', '858 Portage Hill',
#        '629 Grasskamp Junction', '88 Aberg Circle', '18 Morning Circle',
#        '7523 Eggendart Hill', '2 Mandrake Street', '727 Morrow Parkway',
#        '83497 Memorial Plaza', '488 Briar Crest Court',
#        '78451 South Street', '6 Prairieview Pass', '5 Ohio Road',
#        '4787 Golf Terrace', '4 Pine View Junction',
#        '097 Hollow Ridge Alley', '860 Barby Lane', '6412 Butternut Road',
#        '15 Weeping Birch Crossing', '891 Sachtjen Hill',
#        '771 Union Crossing', '22 Farmco Avenue', '01 Bunker Hill Drive',
#        '7650 Gulseth Parkway', '24815 Lindbergh Avenue',
#        '924 Lindbergh Court', '1 Manitowish Court', '9 Derek Alley',
#        '5990 Fairfield Pass', '1 Mandrake Way', '4011 Prairieview Court',
#        '53877 Dakota Crossing', '49 Northfield Drive', '0 Summit Center',
#        '66 Shopko Circle', '370 Eastwood Road', '20 Hoffman Park',
#        '6293 Hooker Point', '30 Harper Trail', '64467 Pankratz Pass',
#        '900 Brown Junction', '8845 Spaight Way', '85420 Myrtle Road',
#        '276 Anthes Court', '6315 Mendota Parkway',
#        '66904 American Ash Hill', '90 Morningstar Drive',
#        '34020 Sheridan Park', '58 Meadow Valley Court',
#        '2030 Anderson Lane', '07 Acker Pass', '31815 Vermont Drive',
#        '5070 Division Parkway', '4 Fordem Avenue', '659 Comanche Plaza',
#        '5 Myrtle Junction', '723 Grayhawk Way', '55 Dorton Point',
#        '9 Killdeer Circle', '04 Miller Drive', '64213 Miller Point',
#        '24593 Jackson Parkway', '9346 Lyons Point', '0504 Nevada Drive',
#        '817 Loftsgordon Road', '30 Lukken Point', '4 Kingsford Trail',
#        '42 3rd Plaza', '6660 Riverside Circle', '21712 Texas Court',
#        '122 Marcy Park', '293 Mendota Park', '47 Scofield Junction',
#        '9 Washington Center', '7109 Grayhawk Avenue', '70 Evergreen Hill',
#        '20139 Lakewood Plaza', '9 Memorial Road', '3094 Elka Place',
#        '31 Schurz Parkway', '85894 Amoth Court', '955 Burning Wood Way',
#        '27 Crownhardt Center', '41002 Loomis Park', '10 Cottonwood Point',
#        '2115 Maryland Alley', '6 Milwaukee Hill', '6792 Kropf Hill',
#        '37 Mesta Road', '85340 Hovde Way', '02643 Moose Court',
#        '59252 Maryland Drive', '2886 Buena Vista Terrace',
#        '58770 Monterey Plaza', '2941 Loftsgordon Hill',
#        '345 Fieldstone Park', '251 Pierstorff Alley', '220 Cody Alley',
#        '34 Bunting Pass', '99 Park Meadow Hill', '4 Bluestem Pass',
#        '078 Erie Point', '6 Hansons Crossing', '8 Saint Paul Junction',
#        '14067 Armistice Plaza', '8491 Pennsylvania Crossing',
#        '59208 Barnett Avenue', '36 Killdeer Crossing',
#        '305 Sloan Junction', '88 Shopko Way', '7 Mallory Lane',
#        '79907 Randy Center', '446 High Crossing Way',
#        '1530 Columbus Lane', '669 Declaration Street', '9 Ruskin Way',
#        '8 Burning Wood Junction', '5 Melvin Park', '21316 Ohio Place',
#        '93 Sutherland Terrace', '1560 Grim Avenue', '1 Quincy Road',
#        '607 Memorial Avenue', '9594 Badeau Street', '9460 Monument Park',
#        '72 Village Terrace', '694 Coolidge Center',
#        '31854 Anniversary Terrace', '125 Manufacturers Parkway',
#        '260 Briar Crest Drive', '56 Moland Crossing', '1 Shelley Pass',
#        '0535 Jay Point', '6 Caliangt Way', '2 Sloan Way',
#        '04 Union Crossing', '33475 Fair Oaks Junction',
#        '57666 Victoria Way', '21875 Grover Drive'], dtype=object)

# %%
new_customer_list['state'].value_counts()
# Out:
# NSW    506
# VIC    266
# QLD    228
# Name: state, dtype: int64

# %%
new_customer_list['country'].unique()
# Out:
# array(['Australia'], dtype=object)

# %% [markdown]
# - All the values are valid, accurate and consistent, except for some missing values in last_name, DOB, job_title, job_industry_category. The number of missing values in DOB and last_name are in small amount, so we might drop them. However, the further step with missing values in other two columns will depend on the final goal of analysis;
# - Lack the explanation of collection of several columns, the meaning for each values. They are deceased_indicator, tenure, property_valuation, Rank and Value. Especially, for the U in gender column, we need to confirm its meaning before futher step;
# - All the values in country and deceased_indicator columns are same, seperately, the further step of these column will depend on the finl goal of analysis.

# %% [markdown]
# # Explore the CustomerDemographic

# %%
# import the NewCustomerList and skip the first row which is note
customer_demographic = pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx',sheet_name='CustomerDemographic', skiprows=1)
customer_demographic.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Health      Mass Customer                  N
# 1    Financial Services      Mass Customer                  N
# 2              Property      Mass Customer                  N
# 3                    IT      Mass Customer                  N
# 4                   NaN  Affluent Customer                  N
#
#                                              default owns_car  tenure
# 0                                                 "'      Yes    11.0
# 1                       <script>alert('hi')</script>      Yes    16.0
# 2                                2018-02-01 00:00:00      Yes    15.0
# 3  () { _; } >_[$($())] { touch /tmp/blns.shellsh...       No     7.0
# 4                                                NIL      Yes     8.0

# %%
# Check the info of the table
customer_demographic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 13 columns):
# customer_id                            4000 non-null int64
# first_name                             4000 non-null object
# last_name                              3875 non-null object
# gender                                 4000 non-null object
# past_3_years_bike_related_purchases    4000 non-null int64
# DOB                                    3913 non-null datetime64[ns]
# job_title                              3494 non-null object
# job_industry_category                  3344 non-null object
# wealth_segment                         4000 non-null object
# deceased_indicator                     4000 non-null object
# default                                3698 non-null object
# owns_car                               4000 non-null object
# tenure                                 3913 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(9)
# memory usage: 406.3+ KB

# %% [markdown]
# For this stage:
#
# - columns with missing values: last_name, DOB, job_title, job_industry_category, default, tenure;
#
# - columns that lack data explanation: deceased_indicator, default and tenure;
# - values in default and gender columns look tanglesome.

# %%
# check the values in default column
customer_demographic['default'].unique()
# Out:
# array(['"\'', "<script>alert('hi')</script>",
#        datetime.datetime(2018, 2, 1, 0, 0),
#        '() { _; } >_[$($())] { touch /tmp/blns.shellshock2.fail; }',
#        'NIL', 'ðµ ð ð ð', 'â°â´âµâââ', '(â¯Â°â¡Â°ï¼â¯ï¸µ â»ââ»)', '0/0',
#        'ð©ð½', 'ÅâÂ´Â®â\xa0Â¥Â¨ËÃ¸Ïââ', 'nil', -100, 'â°â´âµ', 'ð',
#        1000000000000000049861653971908893017010268485438462151574892930611988399099305815384459015356416,
#        'ï¾ï½¥â¿ã¾â²(ï½¡ââ¿âï½¡)â±â¿ï½¥ï¾', 'Î©âÃ§ââ«ËÂµâ¤â¥Ã·',
#        'ÅâÂ´â°ËÃÂ¨ËÃâââ', 'ï¼ï¼ï¼',
#        'ÌÌºÍÌ¹Ì¯ÍTÌ±Ì¤ÍÌ¥ÍÍhÍÌ²eÍÍÌ¼ÌÌÌ¼Ì£Í ÍÌÌ±Ì\xa0ÍÍÍNÍ\xa0ÍeÌÌ±zÌÌÌÌºÍpÌ¤ÌºÌ¹ÍÌ¯ÍeÍÌ\xa0Ì»Ì\xa0rÌ¨Ì¤ÍÌºÌÍÌÌdÍÌ\xa0ÌÌ\xadÌ¬ÌiÌ¦ÍÌ©ÍÍÌ¤aÌ\xa0ÌÌ¬ÍÌnÍÍ Ì»ÌÌ°ÍÍhÌµÍiÌ³ÌvÌ¢ÍeÍÌ\xadÍ-ÒÌ\xadÌ©Ì¼ÍmÌ¤Ì\xadÌ«iÍÍÌÌ¦nÌÍdÌ£Ì ÍÌ¯Ì²ÍoÌ¨ÌÌ¯Ì°Ì²',
#        0, 'â©testâ©', 'â£', 'Ã¥ÃâÆÂ©ËâËÂ¬â¦Ã¦',
#        'ç¤¾æç§å\xad¸é¢èªå\xad¸ç\xa0ç©¶æ', 'âªâªtestâª', 'ï»¿',
#        'â¤ï¸ ð ð ð ð ð ð ð ð ð ð ð ð ð ð', 'â«testâ«', 'â¦testâ§',
#        '\'"\'\'\'\'"', 'â¡', 'ð\xa0ð\xa0±ð\xa0¹ð\xa0±ð\xa0±¸ð\xa0²ð\xa0³'],
#       dtype=object)

# %% [markdown]
# We have to later discuss with the auther of the customer_demographic table about the default column. Then we will take further step depends on the goal of our analysis.

# %%
# Check for null values
customer_demographic.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %% [markdown]
# We will take the further step with the missing values based on the goal of final analysis.

# %%
# Check the duplicates in the table
customer_demographic[customer_demographic.duplicated()].sum()
# Out:
# customer_id                            0.0
# first_name                             0.0
# last_name                              0.0
# gender                                 0.0
# past_3_years_bike_related_purchases    0.0
# DOB                                    0.0
# job_title                              0.0
# job_industry_category                  0.0
# wealth_segment                         0.0
# deceased_indicator                     0.0
# default                                0.0
# owns_car                               0.0
# tenure                                 0.0
# dtype: float64

# %% [markdown]
# There is no duplicates in the customer_demographic.

# %%
# check the descriptive statistics of customer_demographic
customer_demographic.describe()
# Out:
#        customer_id  past_3_years_bike_related_purchases       tenure
# count  4000.000000                          4000.000000  3913.000000
# mean   2000.500000                            48.890000    10.657041
# std    1154.844867                            28.715005     5.660146
# min       1.000000                             0.000000     1.000000
# 25%    1000.750000                            24.000000     6.000000
# 50%    2000.500000                            48.000000    11.000000
# 75%    3000.250000                            73.000000    15.000000
# max    4000.000000                            99.000000    22.000000

# %%
# check the validity and consistence of values in each columns
customer_demographic['DOB'].describe()
# Out:
# count                    3913
# unique                   3448
# top       1978-01-30 00:00:00
# freq                        7
# first     1843-12-21 00:00:00
# last      2002-03-11 00:00:00
# Name: DOB, dtype: object

# %%
# check the distribution of the DOB
customer_demographic['DOB'].groupby([customer_demographic['DOB'].dt.year]).agg('count')
# Out:
# DOB
# 1843.0      1
# 1931.0      1
# 1935.0      1
# 1940.0      1
# 1943.0      1
# 1944.0      1
# 1953.0     19
# 1954.0     61
# 1955.0     58
# 1956.0     63
# 1957.0     71
# 1958.0     55
# 1959.0     94
# 1960.0     58
# 1961.0     60
# 1962.0     76
# 1963.0     59
# 1964.0     85
# 1965.0     69
# 1966.0     65
# 1967.0     73
# 1968.0     69
# 1969.0     78
# 1970.0     57
# 1971.0     88
# 1972.0     54
# 1973.0    122
# 1974.0    152
# 1975.0    114
# 1976.0    152
# 1977.0    204
# 1978.0    217
# 1979.0    118
# 1980.0    123
# 1981.0     79
# 1982.0     41
# 1983.0     40
# 1984.0     43
# 1985.0     91
# 1986.0    114
# 1987.0     72
# 1988.0     72
# 1989.0     74
# 1990.0     53
# 1991.0     48
# 1992.0     74
# 1993.0     60
# 1994.0     79
# 1995.0     90
# 1996.0     67
# 1997.0     74
# 1998.0     80
# 1999.0     60
# 2000.0     42
# 2001.0     34
# 2002.0      6
# Name: DOB, dtype: int64

# %%
customer_demographic['gender'].value_counts()
# Out:
# Female    2037
# Male      1872
# U           88
# Femal        1
# M            1
# F            1
# Name: gender, dtype: int64

# %%
# replace the other values in gender into appropriate values
#https://www.kite.com/python/answers/how-to-replace-column-values-in-a-pandas-dataframe-in-python
customer_demographic['gender'].replace({'M':'Male', 'F': 'Female', 'Femal': 'Female'}, inplace=True)
customer_demographic['gender'].value_counts()
# Out:
# Female    2039
# Male      1873
# U           88
# Name: gender, dtype: int64

# %%
customer_demographic['job_title'].unique()
# Out:
# array(['Executive Secretary', 'Administrative Officer',
#        'Recruiting Manager', nan, 'Senior Editor', 'Media Manager I',
#        'Business Systems Development Analyst', 'Senior Quality Engineer',
#        'Nuclear Power Engineer', 'Developer I', 'Account Executive',
#        'Junior Executive', 'Media Manager IV', 'Sales Associate',
#        'Professor', 'Geological Engineer', 'Project Manager',
#        'Safety Technician I', 'Research Assistant I',
#        'Accounting Assistant III', 'Editor', 'Research Nurse',
#        'Safety Technician III', 'Staff Accountant III', 'Legal Assistant',
#        'Product Engineer', 'Information Systems Manager',
#        'VP Quality Control', 'Social Worker', 'Senior Cost Accountant',
#        'Assistant Media Planner', 'Payment Adjustment Coordinator',
#        'Food Chemist', 'Accountant III', 'Director of Sales',
#        'Senior Financial Analyst', 'Registered Nurse',
#        'Biostatistician II', 'Computer Systems Analyst II',
#        'Software Test Engineer II', 'Paralegal', 'VP Sales',
#        'Chief Design Engineer', 'Office Assistant III',
#        'Physical Therapy Assistant', 'Help Desk Operator',
#        'Web Developer II', 'Research Associate', 'Teacher',
#        'VP Product Management', 'Statistician II',
#        'Automation Specialist IV', 'Data Coordiator',
#        'Software Test Engineer III', 'Internal Auditor',
#        'Analyst Programmer', 'Occupational Therapist',
#        'Speech Pathologist', 'Quality Control Specialist',
#        'Civil Engineer', 'Software Engineer III',
#        'Community Outreach Specialist', 'Safety Technician IV',
#        'VP Accounting', 'General Manager', 'Nurse Practicioner',
#        'Automation Specialist II', 'Marketing Assistant',
#        'Marketing Manager', 'Staff Scientist', 'Assistant Professor',
#        'Budget/Accounting Analyst IV', 'Associate Professor',
#        'Graphic Designer', 'Administrative Assistant II',
#        'Compensation Analyst', 'Systems Administrator III',
#        'Financial Advisor', 'Chemical Engineer', 'Web Designer I',
#        'Senior Developer', 'Office Assistant II', 'Recruiter', 'Operator',
#        'Programmer Analyst III', 'Quality Engineer', 'Environmental Tech',
#        'Analog Circuit Design manager', 'Cost Accountant', 'Librarian',
#        'Structural Analysis Engineer', 'Pharmacist', 'Assistant Manager',
#        'Accountant I', 'Web Designer III', 'Geologist III',
#        'Software Test Engineer I', 'Structural Engineer',
#        'Safety Technician II', 'Web Developer III',
#        'Programmer Analyst II', 'Design Engineer', 'Statistician I',
#        'VP Marketing', 'Desktop Support Technician', 'Actuary',
#        'Database Administrator III', 'Electrical Engineer',
#        'Tax Accountant', 'Clinical Specialist',
#        'Database Administrator IV', 'Systems Administrator II',
#        'Account Coordinator', 'Programmer III',
#        'Administrative Assistant III', 'Nurse', 'Technical Writer',
#        'Staff Accountant II', 'Dental Hygienist', 'Sales Representative',
#        'Budget/Accounting Analyst III', 'Computer Systems Analyst IV',
#        'Geologist I', 'Financial Analyst', 'Accounting Assistant II',
#        'Senior Sales Associate', 'Database Administrator II',
#        'Engineer I', 'Budget/Accounting Analyst I', 'Developer IV',
#        'Database Administrator I', 'Environmental Specialist',
#        'Computer Systems Analyst I', 'Account Representative IV',
#        'Statistician IV', 'Human Resources Manager',
#        'GIS Technical Architect', 'Programmer IV',
#        'Accounting Assistant IV', 'Software Engineer IV', 'Programmer II',
#        'Engineer III', 'Software Consultant', 'Biostatistician IV',
#        'Help Desk Technician', 'Automation Specialist I', 'Developer III',
#        'Human Resources Assistant I', 'Geologist IV', 'Media Manager II',
#        'Statistician III', 'Engineer II', 'Health Coach II',
#        'Developer II', 'Systems Administrator I', 'Web Developer I',
#        'Software Engineer II', 'Accounting Assistant I',
#        'Research Assistant II', 'Programmer Analyst IV', 'Health Coach I',
#        'Accountant II', 'Automation Specialist III',
#        'Administrative Assistant I', 'Health Coach IV',
#        'Media Manager III', 'Account Representative III',
#        'Web Designer IV', 'Budget/Accounting Analyst II',
#        'Web Developer IV', 'Programmer I', 'Biostatistician III',
#        'Software Test Engineer IV', 'Research Assistant IV',
#        'Account Representative I', 'Accountant IV', 'Biostatistician I',
#        'Human Resources Assistant IV', 'Administrative Assistant IV',
#        'Office Assistant I', 'Human Resources Assistant II',
#        'Mechanical Systems Engineer', 'Engineer IV', 'Health Coach III',
#        'Office Assistant IV', 'Software Engineer I',
#        'Human Resources Assistant III', 'Staff Accountant I',
#        'Computer Systems Analyst III', 'Geologist II', 'Web Designer II',
#        'Staff Accountant IV', 'Account Representative II',
#        'Programmer Analyst I', 'Systems Administrator IV',
#        'Research Assistant III'], dtype=object)

# %%
customer_demographic['job_industry_category'].value_counts()
# Out:
# Manufacturing         799
# Financial Services    774
# Health                602
# Retail                358
# Property              267
# IT                    223
# Entertainment         136
# Argiculture           113
# Telecommunications     72
# Name: job_industry_category, dtype: int64

# %%
customer_demographic['wealth_segment'].value_counts()
# Out:
# Mass Customer        2000
# High Net Worth       1021
# Affluent Customer     979
# Name: wealth_segment, dtype: int64

# %%
customer_demographic['deceased_indicator'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
customer_demographic['owns_car'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# - All the values are valid, accurate and consistent, except for some missing values in last_name, DOB, job_title, job_industry_category, default and tenure, as well as the DOB in 1843. Especially, all the values in default column are unreadable. The further step with missing values in these columns will depend on the final goal of analysis;
# - Lack the explanation of collection of several columns, the meaning for each values. They are deceased_indicator, tenure, and default. Especially, for the U in gender column, we need to confirm its meaning before futher step.

# %% [markdown]
# # Explore the CustomerAddress

# %%
# import the CustomerAddress and skip the first row which is note
customer_address = pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx',sheet_name='CustomerAddress', skiprows=1)
customer_address.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
# Check the info of the table
customer_address.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 6 columns):
# customer_id           3999 non-null int64
# address               3999 non-null object
# postcode              3999 non-null int64
# state                 3999 non-null object
# country               3999 non-null object
# property_valuation    3999 non-null int64
# dtypes: int64(3), object(3)
# memory usage: 187.5+ KB

# %% [markdown]
# For this stage:
#
# - No missing values;
#
# - postcode date type should be string, not the integer.

# %%
# convert the date type of postcode to string 
customer_address['postcode'] = customer_address['postcode'].astype(str)
print(customer_address['postcode'].dtypes)
# Out:
# object

# %%
# Check the duplicates in the table
customer_address[customer_address.duplicated()].sum()
# Out:
# customer_id           0.0
# address               0.0
# postcode              0.0
# state                 0.0
# country               0.0
# property_valuation    0.0
# dtype: float64

# %%
# check the descriptive statistics of CustomerAddress
customer_address.describe()
# Out:
#        customer_id  property_valuation
# count  3999.000000         3999.000000
# mean   2003.987997            7.514379
# std    1154.576912            2.824663
# min       1.000000            1.000000
# 25%    1004.500000            6.000000
# 50%    2004.000000            8.000000
# 75%    3003.500000           10.000000
# max    4003.000000           12.000000

# %%
# check the validity and consistence of values in each columns
customer_address['address'].unique()
# Out:
# array(['060 Morning Avenue', '6 Meadow Vale Court', '0 Holy Cross Court',
#        ..., '87 Crescent Oaks Alley', '8194 Lien Street',
#        '320 Acker Drive'], dtype=object)

# %%
customer_address['state'].unique()
# Out:
# array(['New South Wales', 'QLD', 'VIC', 'NSW', 'Victoria'], dtype=object)

# %%
# replace the other values in state into appropriate values
customer_address['state'].replace({'New South Wales':'NSW', 'Victoria': 'VIC'}, inplace=True)
customer_address['state'].value_counts()
# Out:
# NSW    2140
# VIC    1021
# QLD     838
# Name: state, dtype: int64

# %%
customer_address['country'].unique()
# Out:
# array(['Australia'], dtype=object)

# %%
len(customer_address['postcode'].unique())
# Out:
# 873

# %% [markdown]
# - All the values are valid, accurate and consistent. No missing values and duplicates;
# - All values in country column are same, the further step of it depends on the goal of our analysis;
# - customer_address could merge with customer_demographic since they share the same customer_id.

# %% [markdown]
# # Merge the CustomerAddress and CustomerDemographic

# %%
# merge two dataframes as one on the same customer_id
customer_df = pd.merge(customer_demographic, customer_address, how='inner', on='customer_id')
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3996 entries, 0 to 3995
# Data columns (total 18 columns):
# customer_id                            3996 non-null int64
# first_name                             3996 non-null object
# last_name                              3871 non-null object
# gender                                 3996 non-null object
# past_3_years_bike_related_purchases    3996 non-null int64
# DOB                                    3909 non-null datetime64[ns]
# job_title                              3492 non-null object
# job_industry_category                  3341 non-null object
# wealth_segment                         3996 non-null object
# deceased_indicator                     3996 non-null object
# default                                3694 non-null object
# owns_car                               3996 non-null object
# tenure                                 3909 non-null float64
# address                                3996 non-null object
# postcode                               3996 non-null object
# state                                  3996 non-null object
# country                                3996 non-null object
# property_valuation                     3996 non-null int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(13)
# memory usage: 593.2+ KB

# %% [markdown]
# There are in total 3996 rows after mergeing in the new customer dataframe.

# %%
# Check for null values
customer_df.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              504
# job_industry_category                  655
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# dtype: int64

# %%
# Check the duplicates in the table
customer_df[customer_df.duplicated()].sum()
# Out:
# customer_id                            0.0
# first_name                             0.0
# last_name                              0.0
# gender                                 0.0
# past_3_years_bike_related_purchases    0.0
# DOB                                    0.0
# job_title                              0.0
# job_industry_category                  0.0
# wealth_segment                         0.0
# deceased_indicator                     0.0
# default                                0.0
# owns_car                               0.0
# tenure                                 0.0
# address                                0.0
# postcode                               0.0
# state                                  0.0
# country                                0.0
# property_valuation                     0.0
# dtype: float64

# %%
customer_df[customer_df['DOB'].dt.year == 1843]
# Out:
#     customer_id first_name last_name gender  \
# 29           34   Jephthah  Bachmann      U
#
#     past_3_years_bike_related_purchases        DOB        job_title  \
# 29                                   59 1843-12-21  Legal Assistant
#
#    job_industry_category     wealth_segment deceased_indicator default  \
# 29                    IT  Affluent Customer                  N     NaN
#
#    owns_car  tenure         address postcode state    country  \
# 29       No    20.0  833 Luster Way     4005   QLD  Australia
#
#     property_valuation
# 29                   8

# %%
# drop the row which DOB is in 1843
customer_df = customer_df.drop(29)
customer_df['DOB'].describe()
# Out:
# count                    3908
# unique                   3443
# top       1978-01-30 00:00:00
# freq                        7
# first     1931-10-23 00:00:00
# last      2002-03-11 00:00:00
# Name: DOB, dtype: object

# %%
customer_df['owns_car'].value_counts()
# Out:
# Yes    2021
# No     1974
# Name: owns_car, dtype: int64

# %%
# convert postcode to location information 
def get_geocoder(postal_code_from_df):
    g = geocoder.osm('{}, Australia'.format(postal_code_from_df))
    return g.json["lat"],g.json["lng"]

# %%
code_map = {}
for postcode in customer_address['postcode'].unique():
    lat, lng = get_geocoder(postcode)
    code_map[postcode] = (lat, lng)

# %%
len(code_map)
def helper(x):
    return code_map[x][0], code_map[x][1]

# %%
customer_df['latitude'], customer_df['longitude'] = zip(*customer_df['postcode'].apply(helper))
customer_df
# Out:
#       customer_id      first_name      last_name  gender  \
# 0               1         Laraine      Medendorp  Female
# 1               2             Eli        Bockman    Male
# 2               4          Talbot            NaN    Male
# 3               5  Sheila-kathryn         Calton  Female
# 4               6            Curr      Duckhouse    Male
# 5               7            Fina         Merali  Female
# 6               8             Rod          Inder    Male
# 7               9            Mala           Lind  Female
# 8              11           Uriah         Bisatt    Male
# 9              12         Sawyere       Flattman    Male
# 10             13        Gabriele       Norcross    Male
# 11             14        Rayshell       Kitteman  Female
# 12             15          Erroll         Radage    Male
# 13             16          Harlin           Parr    Male
# 14             17           Heath        Faraday    Male
# 15             18          Marjie        Neasham  Female
# 16             19          Sorcha         Keyson  Female
# 17             20          Basile          Firth    Male
# 18             21            Mile       Cammocke    Male
# 19             24             Kim         Skpsey  Female
# 20             25           Geoff          Assaf    Male
# 21             26           Trixi       Ginnelly  Female
# 22             27          Garvin          Klees    Male
# 23             28             Fee        Zellmer    Male
# 24             29            Mona       Sancraft  Female
# 25             30         Darrick      Helleckas    Male
# 26             31            Star         Praton  Female
# 27             32          Marion      Vanichkin  Female
# 28             33           Ernst          Hacon    Male
# 30             35      Margaretha       Strettle  Female
# ...           ...             ...            ...     ...
# 3966         3971         Analise         Asbrey  Female
# 3967         3972       Maribelle       Schaffel  Female
#
#                                  job_title job_industry_category  \
# 0                      Executive Secretary                Health
# 1                   Administrative Officer    Financial Services
# 2                                      NaN                    IT
# 3                            Senior Editor                   NaN
# 4                                      NaN                Retail
# 5                                      NaN    Financial Services
# 6                          Media Manager I                   NaN
# 7     Business Systems Development Analyst           Argiculture
# 8                                      NaN              Property
# 9                   Nuclear Power Engineer         Manufacturing
# 10                             Developer I    Financial Services
# 11                       Account Executive    Financial Services
# 12                        Junior Executive         Manufacturing
# 13                        Media Manager IV                   NaN
# 14                         Sales Associate                   NaN
# 15                               Professor                   NaN
# 16                     Geological Engineer         Manufacturing
# 17                         Project Manager         Manufacturing
# 18                     Safety Technician I         Manufacturing
# 19                    Research Assistant I           Argiculture
# 20                Accounting Assistant III    Financial Services
# 21                                  Editor    Financial Services
# 22                          Research Nurse                Health
# 23                 Senior Quality Engineer                Health
# 24                   Safety Technician III         Manufacturing
# 25                                     NaN                    IT
# 26                    Staff Accountant III    Telecommunications
# 27                         Legal Assistant         Manufacturing
# 28                        Product Engineer                   NaN
# 30             Information Systems Manager                Health
# ...                                    ...                   ...
# 3966            Desktop Support Technician    Financial Services
# 3967                                   NaN                Retail
# 3968                                Editor         Manufacturing
# 3969                      Technical Writer                   NaN
# 3970            Administrative Assistant I         Entertainment
# 3971                      Internal Auditor                   NaN
# 3972                    Biostatistician II         Manufacturing
# 3973                          Developer II    Financial Services
# 3974                                   NaN    Financial Services
# 3975                        Web Designer I         Manufacturing
# 3976            Quality Control Specialist                Health
# 3977                       General Manager         Manufacturing
# 3978                      Graphic Designer                   NaN
# 3979                             Librarian         Entertainment
# 3980                      Web Developer IV              Property
# 3981                         Social Worker                Health
# 3982                                   NaN           Argiculture
# 3983              Automation Specialist IV                Health
# 3984              Environmental Specialist           Argiculture
# 3985            Desktop Support Technician                Health
# 3986                 Chief Design Engineer         Manufacturing
# 3987             Database Administrator IV         Manufacturing
# 3988                             Librarian         Entertainment
# 3989          Structural Analysis Engineer         Manufacturing
# 3990                       Staff Scientist         Manufacturing
# 3991                 VP Product Management                Health
# 3992                       Statistician II         Manufacturing
# 3993                     Assistant Manager                    IT
# 3994                                   NaN         Manufacturing
# 3995                  Software Engineer IV                   NaN
#
#          wealth_segment deceased_indicator  ... tenure  \
# 0         Mass Customer                  N  ...   11.0
# 1         Mass Customer                  N  ...   16.0
# 2         Mass Customer                  N  ...    7.0
# 3     Affluent Customer                  N  ...    8.0
# 4        High Net Worth                  N  ...   13.0
# 5     Affluent Customer                  N  ...   11.0
# 6         Mass Customer                  N  ...    7.0
# 7     Affluent Customer                  N  ...    8.0
# 8         Mass Customer                  N  ...    9.0
# 9         Mass Customer                  N  ...    8.0
# 10       High Net Worth                  N  ...    8.0
# 11    Affluent Customer                  N  ...    6.0
# 12        Mass Customer                  N  ...    1.0
# 13        Mass Customer                  N  ...   18.0
# 14    Affluent Customer                  N  ...   15.0
# 15    Affluent Customer                  N  ...   11.0
# 16       High Net Worth                  N  ...    1.0
# 17        Mass Customer                  N  ...   11.0
# 18    Affluent Customer                  N  ...   16.0
# 19        Mass Customer                  N  ...   15.0
# 18                    7 -35.120263  147.381280 -35.120263  147.381280
# 19                   10 -33.753486  150.998426 -33.753486  150.998426
# 20                    3 -26.740512  150.625649 -26.740512  150.625649
# 21                    5 -21.162949  149.189335 -21.162949  149.189335
# 22                    7 -38.139540  144.350844 -38.139540  144.350844
# 23                    4 -16.986375  145.737687 -16.986375  145.737687
# 24                    7 -27.626762  153.051829 -27.626762  153.051829
# 25                   11 -34.382274  150.876387 -34.382274  150.876387
# 26                   12 -33.877044  151.088579 -33.877044  151.088579
# 27                    9 -33.564140  150.796452 -33.564140  150.796452
# 28                    9 -33.920005  150.924079 -33.920005  150.924079
# 30                    6 -27.622561  153.132949 -27.622561  153.132949
# ...                 ...        ...         ...        ...         ...
# 3966                  8 -34.442999  150.839152 -34.442999  150.839152
# 3967                 11 -37.886371  144.987355 -37.886371  144.987355
# 3968                 10 -33.903514  151.084763 -33.903514  151.084763
# 3969                  8 -38.259887  145.040295 -38.259887  145.040295
# 3970                  9 -33.913072  150.879311 -33.913072  150.879311
# 3971                  7 -38.008560  145.305622 -38.008560  145.305622
# 3972                 11 -37.918921  145.016738 -37.918921  145.016738
# 3973                  7 -34.049091  150.806726 -34.049091  150.806726
# 3974                  8 -33.777514  150.894162 -33.777514  150.894162
# 3975                 10 -33.814750  151.088866 -33.814750  151.088866
# 3976                  9 -37.926582  145.234641 -37.926582  145.234641
# 3977                  9 -33.867820  150.946258 -33.867820  150.946258
# 3978                 10 -33.726078  151.040281 -33.726078  151.040281
# 3979                 10 -33.974833  151.074361 -33.974833  151.074361
# 3980                  5 -27.596854  152.973264 -27.596854  152.973264
# 3981                  9 -33.777514  150.894162 -33.777514  150.894162
# 3982                 10 -28.068229  153.363934 -28.068229  153.363934
# 3983                 11 -33.699971  151.125248 -33.699971  151.125248
# 3984                  2 -32.154684  152.479874 -32.154684  152.479874
# 3985                  8 -34.049091  150.806726 -34.049091  150.806726
# 3986                  5 -27.673761  152.915453 -27.673761  152.915453
# 3987                 11 -33.947479  151.066737 -33.947479  151.066737
# 3988                  6 -37.612437  145.016828 -37.612437  145.016828
# 3989                  2 -37.893353  144.703659 -37.893353  144.703659
# 3990                 12 -33.826098  151.241649 -33.826098  151.241649
# 3991                  6 -38.086180  145.288624 -38.086180  145.288624
# 3992                  2 -30.495313  151.680315 -30.495313  151.680315
# 3993                  6 -34.989807  150.609161 -34.989807  150.609161
# 3994                  3 -37.602511  144.899403 -37.602511  144.899403
# 3995                  6 -26.976553  153.079538 -26.976553  153.079538
#
# [3995 rows x 22 columns]

# %%
location_map = customer_df[['customer_id','postcode','state','latitude','longitude']]
location_map.head()
# Out:
#    customer_id postcode state   latitude   longitude
# 0            1     2016   NSW -33.893169  151.203612
# 1            2     2153   NSW -33.753486  150.998426
# 2            4     4211   QLD -27.995496  153.325939
# 3            5     2448   NSW -30.605714  153.001570
# 4            6     3216   VIC -38.185064  144.343247

# %%
location_map.to_csv('location.csv', index=False)

# %%
# save the dataframe as csv file without index
customer_df.to_csv('customer.csv', index=False)
